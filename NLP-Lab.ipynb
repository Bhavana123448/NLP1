# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavana123448/NLP1/blob/main/NLP-Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 87.1 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize

text = "Natural Language Processing is amazing!"
print(word_tokenize(text))
# Out:
# ['Natural', 'Language', 'Processing', 'is', 'amazing', '!']

# %%
text = """
Natural Language Processing (NLP) is a branch of Artificial Intelligence.
It helps computers understand, analyze, and generate human language.
"""

print(text)
# Out:
# Natural Language Processing (NLP) is a branch of Artificial Intelligence.
# It helps computers understand, analyze, and generate human language.

# %%
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
word_count = len(tokens)
print("Number of words in the text:", word_count)
# Out:
# Number of words in the text: 25

# %%
# Convert entire text to lowercase
lowercase_text = text.lower()

print("Lowercase text:\n", lowercase_text)
# Out:
# Lowercase text:
#
# natural language processing (nlp) is a branch of artificial intelligence.
# it helps computers understand, analyze, and generate human language.
